# %%
# get relevent datta files (.md files in this case) from the input folder and copy them to the raw_data folder
from data_collector import copy_files
input_folder = "repos"
output_folder = "raw_data"

copy_files(input_folder, output_folder)
# Out:
# DEBUG:root:Copied: repos/uxp-photoshop-main/src/pages/index.md -> raw_data/uxp-photoshop-main/src/pages/index.md
# DEBUG:root:Copied: repos/uxp-photoshop-main/src/pages/design/index.md -> raw_data/uxp-photoshop-main/src/pages/design/index.md
# DEBUG:root:Copied: repos/uxp-photoshop-main/src/pages/design/user-interface/index.md -> raw_data/uxp-photoshop-main/src/pages/design/user-interface/index.md
# DEBUG:root:Copied: repos/uxp-photoshop-main/src/pages/design/ux-patterns/Designingforphotoshop.md -> raw_data/uxp-photoshop-main/src/pages/design/ux-patterns/Designingforphotoshop.md
# DEBUG:root:Copied: repos/uxp-photoshop-main/src/pages/design/ux-patterns/messaging.md -> raw_data/uxp-photoshop-main/src/pages/design/ux-patterns/messaging.md
# DEBUG:root:Copied: repos/uxp-photoshop-main/src/pages/design/ux-patterns/branding.md -> raw_data/uxp-photoshop-main/src/pages/design/ux-patterns/branding.md
# ...

# %%
from data_chuncking import split_context_file
input_dir = "raw_data"
output_dir = "chunk_data"
split_context_file(input_dir, output_dir)
# Out:
# DEBUG:root:Processed: chunk_data/uxp-photoshop-main/src/pages/index.md -> processed_data/uxp-photoshop-main/src/pages/index.md
# DEBUG:root:Processed: chunk_data/uxp-photoshop-main/src/pages/design/index.md -> processed_data/uxp-photoshop-main/src/pages/design/index.md
# DEBUG:root:Processed: chunk_data/uxp-photoshop-main/src/pages/design/user-interface/index.md -> processed_data/uxp-photoshop-main/src/pages/design/user-interface/index.md
# DEBUG:root:Processed: chunk_data/uxp-photoshop-main/src/pages/design/ux-patterns/Designingforphotoshop.md -> processed_data/uxp-photoshop-main/src/pages/design/ux-patterns/Designingforphotoshop.md
# DEBUG:root:Processed: chunk_data/uxp-photoshop-main/src/pages/design/ux-patterns/messaging.md -> processed_data/uxp-photoshop-main/src/pages/design/ux-patterns/messaging.md
# DEBUG:root:Processed: chunk_data/uxp-photoshop-main/src/pages/design/ux-patterns/branding.md -> processed_data/uxp-photoshop-main/src/pages/design/ux-patterns/branding.md
# ...
